# %% [markdown]
# # Entanglement In Action

# %% [markdown]
# #### Alice and Bob
# - typical names given to agents in systems that exchange information
# - Assumed to be in different locations
#
# #### Entanglement
# This 2 qubit system - the Phi Plus bell state, shows us an example of entanglement
# - $|\psi> = 1/\sqrt(2)|00> +1/\sqrt(2)|11>$
# - the sum of the two choices squared equals 1 and dont account for the other 2 classical states.
#
# - entanglement is viewed as a resource for specific tasks
# - we can view states like the Phi plus state as a unit of entangement and refer to it as an e-bit
#
# - in our entangled state above, we can say Alice and Bob share the entangled state, with Alice having qubit A and Bob with qubit B

# %% [markdown]
# ## Quantum Teleportation
#
# Q. Teleportaion is the transmission of information through Q. entanglement.
#
# Scenario:
# - Alice has a qubit Q that she wants to transmit to Bob
# - Alice cant send the qubit, she can send classical information to Bob
# - Alice and Bob share an e-bit
# - The state of Q is unknown to Alice and Bob
# - Q might be entangled with other systems and needs to stay that way
# - if Bob recieves the transmission, Alice does not have the Qubit in its original state
#
# - Is there any way to transfer a qubit(quantum information) without the e-bit or without quantum information (using only classical information)?
#     - No lol
#     - No cloning theorem means not all qunatum states can be copied
#         - Classical information can be copied to multiple sources
#         - if we could use classical info to transmit information then we would violate the no-cloning theorem
#
# ![title](12.png)
#
# In this setup, everything above the dotted line is what Alice knows / does, everything below is what Bob recieves
# the 2 qubits at the bottom start at a Phi plus state, these are the e-bit they share
# Qubit Q is the one Alice wants to transfer to Bob
#     we are assuming that Q is in Psi but it could be something else or enangled
# the two doulbe lines from qubit Q and A are the 2 classical bits that Bob recieves
# A and B are in a Phi plus state together
#
# Alice first performs a controlled-NOT operation using Q as the control and A as the target (Q is what she wants to send to bob)
# She then perofrms a Hafamard operation on qubit Q
# She then measures the two qubits A and Q, with respect to standard basis measurements
# Alice sends the measurements to qubit B
#     If the measurement on A is a 1, then B will hava a not operation applied to it
#     If the measurement on Q is a 1, then B will have a  phase phlip operation applied to it

# %% [markdown]
# ### Teleportation analysis
# consider the qubit Q is in the state x|0> + y|1> (x and y still make a unit vector)
# Since Qubit A is in the Phi plus state, we can represetnt the system Pi $_{0}$
# Pi $_{0}$ = |Phi+>(<x|0> + y|1>)
#
# ![title](13.png)
#
# ![title](14.png)
#
# we see that the initial scalars x and y (alpha and beta in the video) have no impact on the probabilities of the state that Bob recieves
# We cant get information on qubit A without disturbing that quantum state
# We cant transmit information to bob without sending anything at all, so once Qubit Q's state has been sent to Qubit B, qubit Q's state is now different, and qubit B is now effectively qubit Q
#
# when the information is transferred, the e-bit is no longer in effect, the states are no longer entangled.
#     the cost of teleportation is one e-bit and 2 classical bits
#
# What if we wanted to perform this with more qubits?
#     Same thing but with more state vectors
#
# #### Explanation
# Alice performs the control not, this sends some info to qubit A, She then performs the Hadamard and measures both bits, the state of B now depends on those classical bits, the state B after the information has been appliex to the Z and X gates now gives it the state Q was in but now the qubits are no longer entangled
#
# #### Remarks
# - teleportation is not an application of quantum information its a way to perform quantum communication
# - teleportation motivates **entanglement distillation** as a means to reliable Q. communication

# %% [markdown]
# ## Superdense Coding
#
# - Allows for 2 classical bits of communication to be packed into one qubit, at the cost of one e-bit
#
# Alice has 2 classical bits that she wants to send to bob,
# alice has sent 1 qubit to bob, so they share an e-bit
#
# without an e-bit, this task would be impossible (holevos theorem - you cant send 2 classical bits of info. with 1 qubit)
#
# ![title](15.png)
#
# if a,b are zero, nothing gets flipped (represented by the identity matrix), the state stays the same
# if a=0, b=1, the phase gets flipped (identity matrix tensored with the Z gaete), the phi plus state becomes a phi minus state
# if a=1,b=0, the state is swapped, phi plus becomes psi plus
# if a=1,b=1, the state and sign swap, phi plis becomes psi minus
#
# #### Remarks
# - superdense coding is not useful in a practical sense
# - the underlying idea is important and gives more info on entanglement
# - together with teleportation, superdense coding creates an equivalence
#     - at the expense of 1 e-bit, we can communicate 1 qubit of quantum information or 2 bits of classical information at the cost of the other

# %% [markdown]
# ## CHSH Game
#
# Not an actual game but an abstraction to illustrate an idea
#
# the CHSH game is an example of a **Non-Local** game
# - Alice and Bob work together, they either win together or lose together
# - Alice and Bob can communicate before the game starts, but once it starts thet can not communicate
#
# - Alice and bob are each asked 1 question( Question X for Alice and Y for Bob).
# - Their answers (a and b) are then given to the referee
#     - in the case of the CHSH game, the questions are bits and the answers are bits
# - The referee decides if they win by if their answers matched the questions X and Y in a particular way
#
# - The referee use randomnes to ask X and Y, so they dont know what they or the other will be asked (prisoner dilemna energy)
#
# - in summary, Alice and bob win if their answers (a,b) are in agreement with the questions (x,y) according to some fixed rule
#     - it is assumed that Alice and Bob Know the rule
#
# CHSH Game referee
# - the questions and answers are all bits {x,y,a,b ∃ {0,1}}
# - x and y are random, meaning x y is randomly any of the 4 states of 2 bits
# - ![title](16.png)
#
# There exists no deterministic strategy that wins each time
# the best case is 3/4 chance
#
# **Can a quantum strategy do better?**
#
# define a quantum state vector |A> for an angle theta, defined as
# $|A _{\theta}> = cos(\theta)|0> + sin(\theta)|1>$
#
# next, define a unitary matrix defined as the cross between Psi of two orthogonal angles theta applied to ket 0 and ket 1
#
#
# Alice and bob share an e-bit (A,B) in the phi plus state
#
# If Alice recieves a 0 then she does nothing (Unitary Matrix with angle 0)
# If Alice recieves a 1, then she applies a unitary operation (The unitary matrix with angle pi/4 )to A
#
# If Bob recieves a 0, then he applies a unitary operation (The unitary matrix with angle pi/8 )to B
# If Bob recieves a 1, then he applies a unitary operation (The unitary matrix with angle -pi/8 )to B
#
# ![title](17.png)
#
# This gives them a .85 probability of winning
